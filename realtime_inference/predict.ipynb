# %%
# !pip install ultralytics
# Out:
# ...
#                                               0.0/757.9 kB ? eta -:--:--
#                                            20.5/757.9 kB 640.0 kB/s eta 0:00:02
#      -                                     41.0/757.9 kB 487.6 kB/s eta 0:00:02
#      ---                                   71.7/757.9 kB 558.5 kB/s eta 0:00:02
#      ----                                 102.4/757.9 kB 587.0 kB/s eta 0:00:02
#      ------                               143.4/757.9 kB 655.8 kB/s eta 0:00:01
#      --------                             174.1/757.9 kB 655.4 kB/s eta 0:00:01
#      ----------                           225.3/757.9 kB 687.0 kB/s eta 0:00:01
#      ------------                         256.0/757.9 kB 682.7 kB/s eta 0:00:01
#      -------------                        286.7/757.9 kB 707.1 kB/s eta 0:00:01
#      ---------------                      317.4/757.9 kB 701.4 kB/s eta 0:00:01
#      ----------------                     348.2/757.9 kB 696.7 kB/s eta 0:00:01
# ...

# %%
from ultralytics import YOLO

model = YOLO("best.pt")

model.predict(0, save=True, conf=0.4, show=True)
# Out:
# 1/1: 0... Success  (inf frames of shape 1280x720 at 30.00 FPS)
#
#
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 384x640 (no detections), 155.3ms
# 0: 384x640 (no detections), 126.0ms
# 0: 384x640 (no detections), 127.5ms
# 0: 384x640 (no detections), 143.2ms
# 0: 384x640 (no detections), 127.5ms
# 0: 384x640 (no detections), 117.0ms
# 0: 384x640 (no detections), 120.8ms
# 0: 384x640 (no detections), 124.5ms
# 0: 384x640 (no detections), 137.2ms
# ...
